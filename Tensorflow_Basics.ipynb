# %%
# !pip install tensorflow==2.19.1
# Out:
# Requirement already satisfied: tensorflow==2.19.1 in /usr/local/lib/python3.12/dist-packages (2.19.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (2.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.1) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.19.1) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.1) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.1) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.1) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.1) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.1) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.1) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.1) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow==2.19.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow==2.19.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.19.1) (0.1.2)

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From /tmp/ipython-input-3934639393.py:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2.19.1
# False

# %% [markdown]
# # Tensorflow Operations

# %% [markdown]
# ## Arithmetic Operation

# %% [markdown]
# In TensorFlow, a constant is a tensor whose value cannot change once it is created. Think of it like a fixed number or array stored in memory that TensorFlow will always treat as the same.
#
# Difference between constant and variable in TensorFlow
#
# | Feature    | tf.constant                 | tf.Variable                     |
# | ---------- | --------------------------- | ------------------------------- |
# | Mutability | Cannot change               | Can change (trainable)          |
# | Use case   | Fixed values in computation | Model parameters (weights/bias) |
# | Example    | `tf.constant([1,2,3])`      | `tf.Variable([1,2,3])`          |

# %%
import tensorflow as tf

# Create tensors
a = tf.constant([1, 2, 3])
b = tf.constant([4, 5, 6])

# Addition
print(tf.add(a, b))

# Subtraction
print(tf.subtract(a, b))

# Multiplication
print(tf.multiply(a, b))

# Division
print(tf.divide(a, b))

# Power
print(tf.pow(a, 2))
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)
# tf.Tensor([-3 -3 -3], shape=(3,), dtype=int32)
# tf.Tensor([ 4 10 18], shape=(3,), dtype=int32)
# tf.Tensor([0.25 0.4  0.5 ], shape=(3,), dtype=float64)
# tf.Tensor([1 4 9], shape=(3,), dtype=int32)

# %% [markdown]
# ## Reduction Operations

# %%
x = tf.constant([1, 2, 3, 4])

print("Sum:", tf.reduce_sum(x))
print("Mean:", tf.reduce_mean(x))
print("Max:", tf.reduce_max(x))
print("Min:", tf.reduce_min(x))
# Out:
# Sum: tf.Tensor(10, shape=(), dtype=int32)
# Mean: tf.Tensor(2, shape=(), dtype=int32)
# Max: tf.Tensor(4, shape=(), dtype=int32)
# Min: tf.Tensor(1, shape=(), dtype=int32)

# %% [markdown]
# ## Trigonometric Operations

# %%
angle = tf.constant([0.0, 3.14159/2, 3.14159])  # in radians

print("Sine:", tf.sin(angle))
print("Cosine:", tf.cos(angle))
print("Tangent:", tf.tan(angle))
# Out:
# Sine: tf.Tensor([0.0000000e+00 1.0000000e+00 2.5351817e-06], shape=(3,), dtype=float32)
# Cosine: tf.Tensor([ 1.0000000e+00  1.2675908e-06 -1.0000000e+00], shape=(3,), dtype=float32)
# Tangent: tf.Tensor([ 0.0000000e+00  7.8889806e+05 -2.5351817e-06], shape=(3,), dtype=float32)

# %% [markdown]
# ## Linear Algebra Operations

# %%
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([[5, 6], [7, 8]])

print("Matrix Multiply:\n", tf.matmul(a, b))
print("Transpose:\n", tf.transpose(a))
# Out:
# Matrix Multiply:
#  tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)
# Transpose:
#  tf.Tensor(
# [[1 3]
#  [2 4]], shape=(2, 2), dtype=int32)

# %% [markdown]
# ## Comparison Operations

# %%
x = tf.constant([1, 2, 3])
y = tf.constant([3, 2, 1])

print(tf.equal(x, y))
print(tf.greater(x, y))
print(tf.less_equal(x, y))
# Out:
# tf.Tensor([False  True False], shape=(3,), dtype=bool)
# tf.Tensor([False False  True], shape=(3,), dtype=bool)
# tf.Tensor([ True  True False], shape=(3,), dtype=bool)

# %% [markdown]
# ## Slicing

# %%
# 1D tensor
a = tf.constant([10, 20, 30, 40, 50])

# Slice from index 1 to 3 (3 not included)
print(a[1:4])

# Slice from start to index 2
print(a[:3])

# Slice from index 2 to end
print(a[2:])

# Slice with step
print(a[::2])
# Out:
# tf.Tensor([20 30 40], shape=(3,), dtype=int32)
# tf.Tensor([10 20 30], shape=(3,), dtype=int32)
# tf.Tensor([30 40 50], shape=(3,), dtype=int32)
# tf.Tensor([10 30 50], shape=(3,), dtype=int32)

# %%
# 2D tensor
b = tf.constant([[1, 2, 3],
                 [4, 5, 6],
                 [7, 8, 9]])

# Slice first two rows, all columns
print(b[:2, :])

# Slice all rows, first two columns
print(b[:, :2])

# Slice a submatrix (rows 1-2, columns 1-2)
print(b[1:, 1:3])
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)
# tf.Tensor(
# [[1 2]
#  [4 5]
#  [7 8]], shape=(3, 2), dtype=int32)
# tf.Tensor(
# [[5 6]
#  [8 9]], shape=(2, 2), dtype=int32)

# %%
# tf.slice(input, begin, size)
# begin: starting index
# size: number of elements to take

c = tf.constant([[10, 20, 30],
                 [40, 50, 60],
                 [70, 80, 90]])

# Take 2 rows, 2 columns starting from (0,1)
sliced = tf.slice(c, [0, 1], [2, 2])
print(sliced)
# [[20 30]
#  [50 60]]
# Out:
# tf.Tensor(
# [[20 30]
#  [50 60]], shape=(2, 2), dtype=int32)

# %% [markdown]
# ## Broadcasting

# %%
a = tf.constant(5)  # scalar
b = tf.broadcast_to(a, [3])
print(b)
# Out:
# tf.Tensor([5 5 5], shape=(3,), dtype=int32)

# %% [markdown]
# # Placeholder
#
# A placeholder is a tensor that we declare, but we don’t give it a value yet.
#
# You can feed it data later during computation.
#
# Placeholders were mainly used in TensorFlow 1.x to build computational graphs before running them.
#
# In TensorFlow 2.x (eager execution), placeholders are no longer needed, because you can directly pass data to tensors or functions.

# %%
tf.disable_v2_behavior()  # Disable TF2 behavior

# Create a placeholder for a float32 tensor
x = tf.placeholder(tf.float32, shape=(None, 2))  # None means any number of rows
y = tf.placeholder(tf.float32, shape=(None, 2))

# Define an operation
z = x + y

with tf.Session() as sess:
    # Feed values to placeholders
    result = sess.run(z, feed_dict={x: [[1,2],[3,4]], y: [[5,6],[7,8]]})
    print(result)
# Out:
# [[ 6.  8.]
#  [10. 12.]]

# %% [markdown]
# # Computational Graph
#
# A computational graph is a network of nodes and edges that represents mathematical computations.
#
# - Nodes: represent operations (like addition, multiplication, or functions) or variables/constants.
# - Edges: represent tensors (data) flowing between operations.
#
# - It allows TensorFlow to optimize and run computations efficiently.
#
# Think of it like a flowchart of math operations, where data flows through a network of operations to produce the result.
#
# ### Why Computational Graphs?
#
# - Lazy execution (in TF1.x): You can define all operations first, then execute them later with specific inputs.
#
# - Optimizations: TensorFlow can parallelize operations and run efficiently on CPU, GPU, or TPU.
#
# - Automatic differentiation: TensorFlow can compute gradients for training neural networks automatically.

# %%
tf.disable_v2_behavior()  # Disable eager execution

# Define placeholders (inputs)
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)

# Define operations (nodes in the graph)
z = x * y + 2

# Create a session to execute the graph
with tf.Session() as sess:
    result = sess.run(z, feed_dict={x: 3, y: 4})
    print(result)  # 14
# Out:
# 14.0

# %% [markdown]
# # Session
#
# A session is a runtime environment in TensorFlow 1.x where computational graphs are executed.
#
# In TensorFlow 1.x, you define the graph first (placeholders, operations, constants)
#
# Then, you run the graph inside a session using sess.run().
#
# Think of a session as the engine that actually computes the results.

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()  # Disable TF2 eager execution

# Define a computational graph
a = tf.constant(5)
b = tf.constant(3)
c = a + b  # Operation node

# Create a session
with tf.Session() as sess:
    result = sess.run(c)  # Execute the graph
    print(result)
# Out:
# 8
